# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.utils import plot_model

#  Import and read the Heart Disease - FOR ML.csv.
dataset_df = pd.read_csv('Heart Disease - FOR ML.csv')
dataset_df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease  Patient ID
# 0                        3         3      Presence       31065
# 1                        0         7       Absence       31606
# 2                        0         7      Presence       32147
# 3                        1         7       Absence       32688
# 4                        1         3       Absence       33229

# %%
# Map string values to integers
mapping = {'Absence': 0, 'Presence': 1}

# Apply mapping to string column
dataset_df['Heart Disease'] = dataset_df['Heart Disease'].map(mapping)

# %%
dataset_df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease  Patient ID
# 0                        3         3              1       31065
# 1                        0         7              0       31606
# 2                        0         7              1       32147
# 3                        1         7              0       32688
# 4                        1         3              0       33229

# %%
# Drop the non-beneficial ID columns, 'FBS over 120' and 'Patient ID'.
dataset_df = dataset_df.drop(columns =['Patient ID'])
dataset_df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# 2                        0         7              1
# 3                        1         7              0
# 4                        1         3              0

# %%
# Determine the number of unique values in each column.
dataset_df.nunique()
# Out:
# Age                         41
# Sex                          2
# Chest pain type              4
# BP                          47
# Cholesterol                144
# FBS over 120                 2
# EKG results                  3
# Max HR                      90
# Exercise angina              2
# ST depression               39
# Slope of ST                  3
# Number of vessels fluro      4
# Thallium                     3
# Heart Disease                2
# dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(dataset_df)
dummies.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0                        3         3              1
# 1                        0         7              0
# 2                        0         7              1
# 3                        1         7              0
# 4                        1         3              0

# %%
# Split our preprocessed data into our features and target arrays
y = dummies['Heart Disease'].values
X = dummies[['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium']].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# (FIRST ATTEMPT - 73% accuracy)
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 8)                 104
#
#  dense_6 (Dense)             (None, 5)                 45
#
#  dense_7 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 155 (620.00 Byte)
# Trainable params: 155 (620.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model (FIRST ATTEMPT)
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model (FIRST ATTEMPT)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7329 - accuracy: 0.5050
# Epoch 2/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7179 - accuracy: 0.5446
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7058 - accuracy: 0.5446
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6945 - accuracy: 0.5594
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6844 - accuracy: 0.5644
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6758 - accuracy: 0.5743
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6683 - accuracy: 0.5792
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.5941
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6533 - accuracy: 0.5990
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6458 - accuracy: 0.6188
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6383 - accuracy: 0.6386
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6306 - accuracy: 0.6485
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6217 - accuracy: 0.6782
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6133 - accuracy: 0.6980
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6044 - accuracy: 0.7129
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5956 - accuracy: 0.7178
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5863 - accuracy: 0.7228
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5775 - accuracy: 0.7327
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5681 - accuracy: 0.7327
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5586 - accuracy: 0.7475
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5488 - accuracy: 0.7673
# Epoch 22/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5392 - accuracy: 0.7772
# Epoch 23/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5284 - accuracy: 0.7921
# Epoch 24/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5180 - accuracy: 0.7970
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5081 - accuracy: 0.8069
# Epoch 26/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.8119
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.8168
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.8168
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4665 - accuracy: 0.8218
# Epoch 30/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.8267
# Epoch 31/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4455 - accuracy: 0.8366
# Epoch 32/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4336 - accuracy: 0.8515
# Epoch 33/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4225 - accuracy: 0.8713
# Epoch 34/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4106 - accuracy: 0.8713
# Epoch 35/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4004 - accuracy: 0.8713
# Epoch 36/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3912 - accuracy: 0.8713
# Epoch 37/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8713
# Epoch 38/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3747 - accuracy: 0.8713
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3675 - accuracy: 0.8713
# Epoch 40/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3611 - accuracy: 0.8762
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8762
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8762
# Epoch 43/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3439 - accuracy: 0.8812
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3385 - accuracy: 0.8812
# Epoch 45/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3336 - accuracy: 0.8861
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3290 - accuracy: 0.8861
# Epoch 47/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3242 - accuracy: 0.8861
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.8911
# Epoch 49/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3164 - accuracy: 0.8960
# Epoch 50/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3125 - accuracy: 0.8960
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3090 - accuracy: 0.8960
# Epoch 52/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3052 - accuracy: 0.8960
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8960
# Epoch 54/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2989 - accuracy: 0.8960
# Epoch 55/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.8960
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2932 - accuracy: 0.8960
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2904 - accuracy: 0.8960
# Epoch 58/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8960
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2857 - accuracy: 0.8960
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8960
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2811 - accuracy: 0.8960
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8960
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.9010
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2744 - accuracy: 0.9010
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2723 - accuracy: 0.9010
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2702 - accuracy: 0.9010
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2683 - accuracy: 0.9010
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2666 - accuracy: 0.9010
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2647 - accuracy: 0.9010
# Epoch 70/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.9059
# Epoch 71/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.9059
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2601 - accuracy: 0.9059
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2585 - accuracy: 0.9010
# Epoch 74/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2572 - accuracy: 0.9010
# Epoch 75/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2559 - accuracy: 0.9010
# Epoch 76/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2548 - accuracy: 0.9059
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.9059
# Epoch 78/100
# 7/7 [==============================] - 0s 925us/step - loss: 0.2523 - accuracy: 0.9010
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2510 - accuracy: 0.9059
# Epoch 80/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2498 - accuracy: 0.9059
# Epoch 81/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2487 - accuracy: 0.9109
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2476 - accuracy: 0.9109
# Epoch 83/100
# 7/7 [==============================] - 0s 1000us/step - loss: 0.2469 - accuracy: 0.9109
# Epoch 84/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.9109
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2447 - accuracy: 0.9109
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2437 - accuracy: 0.9158
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2428 - accuracy: 0.9158
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.9158
# Epoch 89/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.9158
# Epoch 90/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2397 - accuracy: 0.9158
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2388 - accuracy: 0.9158
# Epoch 92/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2379 - accuracy: 0.9158
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2370 - accuracy: 0.9158
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2362 - accuracy: 0.9158
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2354 - accuracy: 0.9158
# Epoch 96/100
# 7/7 [==============================] - 0s 919us/step - loss: 0.2348 - accuracy: 0.9208
# Epoch 97/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 0.9208
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9208
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9208
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2315 - accuracy: 0.9257

# %%
# Evaluate the model using the test data (FIRST ATTEMPT)
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.6022 - accuracy: 0.7206 - 98ms/epoch - 33ms/step
# Loss: 0.6022078394889832, Accuracy: 0.720588207244873

# %%
 # !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\alexh\anaconda3\lib\site-packages (1.4.7)
# Requirement already satisfied: keras in c:\users\alexh\anaconda3\lib\site-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in c:\users\alexh\anaconda3\lib\site-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in c:\users\alexh\anaconda3\lib\site-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in c:\users\alexh\anaconda3\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexh\anaconda3\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexh\anaconda3\lib\site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexh\anaconda3\lib\site-packages (from requests->keras-tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexh\anaconda3\lib\site-packages (from requests->keras-tuner) (2024.2.2)

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=2), activation=activation, input_dim=input_features_total))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=2)
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 74 Complete [00h 00m 02s]
# val_accuracy: 0.5588235259056091
#
# Best val_accuracy So Far: 0.779411792755127
# Total elapsed time: 01h 09m 46s
#
# Search: Running Trial #75
#
# Value             |Best Value So Far |Hyperparameter
# sigmoid           |tanh              |activation
# 71                |41                |first_units
# 3                 |4                 |num_layers
# 7                 |87                |units_0
# 1                 |15                |units_1
# 87                |31                |units_2
# 73                |55                |units_3
# 17                |51                |units_4
# 67                |77                |units_5
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 4                 |4                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[106], line 2
#       1 # Run the kerastuner search for best hyperparameters
# ----> 2 tuner.search(X_train_scaled,y_train,epochs=100,validation_data=(X_test_scaled,y_test))
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\tuners\hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:888, in Function._call(self, *args, **kwds)
#     885 try:
#     886   # This is the first call of __call__, so we have to initialize.
#     887   initializers = []
# --> 888   self._initialize(args, kwds, add_initializers_to=initializers)
#     889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File ~\AppData\Local\Temp\__autograph_generated_filej0yp4rkp.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1384, in Model.make_train_function.<locals>.step_function(model, iterator)
#    1380     run_step = tf.function(
#    1381         run_step, jit_compile=True, reduce_retracing=True
#    1382     )
#    1383 data = next(iterator)
# -> 1384 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    1385 outputs = reduce_per_replica(
#    1386     outputs,
#    1387     self.distribute_strategy,
#    1388     reduction=self.distribute_reduction_method,
#    1389 )
#    1390 return outputs
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1681, in StrategyBase.run(***failed resolving arguments***)
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3271, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3269   kwargs = {}
#    3270 with self._container_strategy().scope():
# -> 3271   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4069, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4067 def _call_for_each_replica(self, fn, args, kwargs):
#    4068   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069     return fn(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1373, in Model.make_train_function.<locals>.step_function.<locals>.run_step(data)
#    1372 def run_step(data):
# -> 1373     outputs = model.train_step(data)
#    1374     # Ensure counter is updated only if `train_step` succeeds.
#    1375     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~\anaconda3\Lib\site-packages\keras\src\engine\training.py:1154, in Model.train_step(self, data)
#    1152 self._validate_target_and_loss(y, loss)
#    1153 # Run backwards pass.
# -> 1154 self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#    1155 return self.compute_metrics(x, y, y_pred, sample_weight)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:544, in _BaseOptimizer.minimize(self, loss, var_list, tape)
#     523 """Minimize `loss` by updating `var_list`.
#     524
#     525 This method simply computes gradient using `tf.GradientTape` and calls
#    (...)
#     541   None
#     542 """
#     543 grads_and_vars = self.compute_gradients(loss, var_list, tape)
# --> 544 self.apply_gradients(grads_and_vars)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:1223, in Optimizer.apply_gradients(self, grads_and_vars, name, skip_gradients_aggregation, **kwargs)
#    1221 if not skip_gradients_aggregation and experimental_aggregate_gradients:
#    1222     grads_and_vars = self.aggregate_gradients(grads_and_vars)
# -> 1223 return super().apply_gradients(grads_and_vars, name=name)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:652, in _BaseOptimizer.apply_gradients(self, grads_and_vars, name)
#     650 self._apply_weight_decay(trainable_variables)
#     651 grads_and_vars = list(zip(grads, trainable_variables))
# --> 652 iteration = self._internal_apply_gradients(grads_and_vars)
#     654 # Apply variable constraints after applying gradients.
#     655 for variable in trainable_variables:
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:1253, in Optimizer._internal_apply_gradients(self, grads_and_vars)
#    1249 if self._mesh or self._run_with_dtensor:
#    1250     # Skip any usage of strategy logic for DTensor
#    1251     return super()._internal_apply_gradients(grads_and_vars)
# -> 1253 return tf.__internal__.distribute.interim.maybe_merge_call(
#    1254     self._distributed_apply_gradients_fn,
#    1255     self._distribution_strategy,
#    1256     grads_and_vars,
#    1257 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:1345, in Optimizer._distributed_apply_gradients_fn(self, distribution, grads_and_vars, **kwargs)
#    1342         return self._update_step(grad, var)
#    1344 for grad, var in grads_and_vars:
# -> 1345     distribution.extended.update(
#    1346         var, apply_grad_to_update_var, args=(grad,), group=False
#    1347     )
#    1349 if self.use_ema:
#    1350     _, var_list = zip(*grads_and_vars)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3015, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3013     return self._update(var, fn, args, kwargs, group)
#    3014 else:
# -> 3015   return self._replica_ctx_update(
#    3016       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2894, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2891 def merge_fn(_, *merged_args, **merged_kwargs):
#    2892   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2894 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3486, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3482   kwargs = {}
#    3484 merge_fn = autograph.tf_convert(
#    3485     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3486 return self._merge_call(merge_fn, args, kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3493, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3490 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3491     _CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3492 try:
# -> 3493   return merge_fn(self._strategy, *args, **kwargs)
#    3494 finally:
#    3495   _pop_per_thread_mode()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2892, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2891 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2892   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3013, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3010   fn = autograph.tf_convert(
#    3011       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3012   with self._container_strategy().scope():
# -> 3013     return self._update(var, fn, args, kwargs, group)
#    3014 else:
#    3015   return self._replica_ctx_update(
#    3016       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4083, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4080 def _update(self, var, fn, args, kwargs, group):
#    4081   # The implementations of _update() and _update_non_slot() are identical
#    4082   # except _update() passes `var` as the first argument to `fn()`.
# -> 4083   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4089, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4085 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4086   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4087   # once that value is used for something.
#    4088   with UpdateContext(colocate_with):
# -> 4089     result = fn(*args, **kwargs)
#    4090     if should_group:
#    4091       return result
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:1342, in Optimizer._distributed_apply_gradients_fn.<locals>.apply_grad_to_update_var(var, grad)
#    1340     return self._update_step_xla(grad, var, id(self._var_key(var)))
#    1341 else:
# -> 1342     return self._update_step(grad, var)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\optimizer.py:241, in _BaseOptimizer._update_step(self, gradient, variable)
#     232 if self._var_key(variable) not in self._index_dict:
#     233     raise KeyError(
#     234         f"The optimizer cannot recognize variable {variable.name}. "
#     235         "This usually means you are trying to call the optimizer to "
#    (...)
#     239         f"`tf.keras.optimizers.legacy.{self.__class__.__name__}."
#     240     )
# --> 241 self.update_step(gradient, variable)
#
# File ~\anaconda3\Lib\site-packages\keras\src\optimizers\adam.py:167, in Adam.update_step(self, gradient, variable)
#     165 lr = tf.cast(self.learning_rate, variable.dtype)
#     166 local_step = tf.cast(self.iterations + 1, variable.dtype)
# --> 167 beta_1_power = tf.pow(tf.cast(self.beta_1, variable.dtype), local_step)
#     168 beta_2_power = tf.pow(tf.cast(self.beta_2, variable.dtype), local_step)
#     170 var_key = self._var_key(variable)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\math_ops.py:695, in pow(x, y, name)
#     673 r"""Computes the power of one value to another.
#     674
#     675 Given a tensor `x` and a tensor `y`, this operation computes \\(x^y\\) for
#    (...)
#     692   A `Tensor`.
#     693 """
#     694 with ops.name_scope(name, "Pow", [x]) as name:
# --> 695   return gen_math_ops._pow(x, y, name=name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:7297, in _pow(x, y, name)
#    7295     pass  # Add nodes to the TensorFlow graph.
#    7296 # Add nodes to the TensorFlow graph.
# -> 7297 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    7298       "Pow", x=x, y=y, name=name)
#    7299 _result = _outputs[:]
#    7300 if _execute.must_record_gradient():
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:2652, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2649 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2650 # Session.run call cannot occur between creating and mutating the op.
#    2651 with self._mutation_lock():
# -> 2652   ret = Operation.from_node_def(
#    2653       node_def,
#    2654       self,
#    2655       inputs=inputs,
#    2656       output_types=dtypes,
#    2657       control_inputs=control_inputs,
#    2658       input_types=input_types,
#    2659       original_op=self._default_original_op,
#    2660       op_def=op_def,
#    2661   )
#    2662   self._create_op_helper(ret, compute_device=compute_device)
#    2663 return ret
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1160, in Operation.from_node_def(***failed resolving arguments***)
#    1157     control_input_ops.append(control_op)
#    1159 # Initialize c_op from node_def and other inputs
# -> 1160 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1161 self = Operation(c_op, SymbolicTensor)
#    1162 self._init(g)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\framework\ops.py:1017, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1013   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1014                                          serialized)
#    1016 try:
# -> 1017   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1018 except errors.InvalidArgumentError as e:
#    1019   # Convert to ValueError for backwards compatibility.
#    1020   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2321 - accuracy: 0.9208
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2296 - accuracy: 0.9257
# Epoch 3/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2290 - accuracy: 0.9257
# Epoch 4/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2284 - accuracy: 0.9257
# Epoch 5/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2275 - accuracy: 0.9257
# Epoch 6/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2268 - accuracy: 0.9257
# Epoch 7/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.9257
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2253 - accuracy: 0.9257
# Epoch 9/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2244 - accuracy: 0.9257
# Epoch 10/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9257
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2229 - accuracy: 0.9257
# Epoch 12/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2224 - accuracy: 0.9257
# Epoch 13/100
# 7/7 [==============================] - 0s 1000us/step - loss: 0.2214 - accuracy: 0.9257
# Epoch 14/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2208 - accuracy: 0.9257
# Epoch 15/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2203 - accuracy: 0.9257
# Epoch 16/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2194 - accuracy: 0.9257
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2187 - accuracy: 0.9257
# Epoch 18/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 0.9257
# Epoch 19/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2176 - accuracy: 0.9257
# Epoch 20/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9257
# Epoch 21/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2162 - accuracy: 0.9257
# Epoch 22/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2155 - accuracy: 0.9257
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 0.9257
# Epoch 24/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9307
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2138 - accuracy: 0.9307
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2131 - accuracy: 0.9307
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.9307
# Epoch 28/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.9307
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2114 - accuracy: 0.9307
# Epoch 30/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2107 - accuracy: 0.9307
# Epoch 31/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9307
# Epoch 32/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 0.9307
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9307
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.9307
# Epoch 35/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9307
# Epoch 36/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2074 - accuracy: 0.9307
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2070 - accuracy: 0.9307
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2062 - accuracy: 0.9307
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2059 - accuracy: 0.9307
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2054 - accuracy: 0.9356
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2046 - accuracy: 0.9356
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.9356
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2035 - accuracy: 0.9356
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2031 - accuracy: 0.9356
# Epoch 45/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2026 - accuracy: 0.9356
# Epoch 46/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2022 - accuracy: 0.9356
# Epoch 47/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2016 - accuracy: 0.9307
# Epoch 48/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2007 - accuracy: 0.9307
# Epoch 49/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2004 - accuracy: 0.9307
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.9307
# Epoch 51/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1994 - accuracy: 0.9307
# Epoch 52/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1989 - accuracy: 0.9307
# Epoch 53/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.9307
# Epoch 54/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1982 - accuracy: 0.9307
# Epoch 55/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1978 - accuracy: 0.9307
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9307
# Epoch 57/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9307
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.9307
# Epoch 59/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1959 - accuracy: 0.9307
# Epoch 60/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1956 - accuracy: 0.9307
# Epoch 61/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1951 - accuracy: 0.9307
# Epoch 62/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1947 - accuracy: 0.9307
# Epoch 63/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1942 - accuracy: 0.9307
# Epoch 64/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1937 - accuracy: 0.9307
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1933 - accuracy: 0.9307
# Epoch 66/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1930 - accuracy: 0.9356
# Epoch 67/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1925 - accuracy: 0.9307
# Epoch 68/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.9356
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1918 - accuracy: 0.9356
# Epoch 70/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1913 - accuracy: 0.9356
# Epoch 71/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9356
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1903 - accuracy: 0.9356
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1900 - accuracy: 0.9356
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1897 - accuracy: 0.9356
# Epoch 75/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1893 - accuracy: 0.9356
# Epoch 76/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1890 - accuracy: 0.9307
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9307
# Epoch 78/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.9307
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9307
# Epoch 80/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.9307
# Epoch 81/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1870 - accuracy: 0.9307
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9307
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.9307
# Epoch 84/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1855 - accuracy: 0.9307
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1852 - accuracy: 0.9307
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1848 - accuracy: 0.9307
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9307
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9307
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9307
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9307
# Epoch 91/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1829 - accuracy: 0.9307
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1825 - accuracy: 0.9307
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1819 - accuracy: 0.9307
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1818 - accuracy: 0.9307
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.9307
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1809 - accuracy: 0.9307
# Epoch 97/100
# 7/7 [==============================] - 0s 873us/step - loss: 0.1804 - accuracy: 0.9307
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1800 - accuracy: 0.9307
# Epoch 99/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1796 - accuracy: 0.9307
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1791 - accuracy: 0.9307

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000002F062CE1760> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 - 0s - loss: 0.7114 - accuracy: 0.7059 - 102ms/epoch - 34ms/step
# Loss: 0.7113818526268005, Accuracy: 0.7058823704719543

# %%
# (SECOND ATTEMPT - 73% accuracy)
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5

nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "relu"))

# Second hidden layer
nn_2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "relu"))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 8)                 104
#
#  dense_9 (Dense)             (None, 5)                 45
#
#  dense_10 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 155 (620.00 Byte)
# Trainable params: 155 (620.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model (SECOND ATTEMPT)
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model (SECOND ATTEMPT)
fit_model = nn_2.fit(X_train_scaled,y_train,epochs=150)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 1s 1ms/step - loss: 0.7859 - accuracy: 0.4455
# Epoch 2/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7585 - accuracy: 0.4752
# Epoch 3/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7318 - accuracy: 0.5050
# Epoch 4/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7083 - accuracy: 0.5347
# Epoch 5/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6859 - accuracy: 0.5644
# Epoch 6/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.5792
# Epoch 7/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6467 - accuracy: 0.5891
# Epoch 8/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6302 - accuracy: 0.5941
# Epoch 9/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6145 - accuracy: 0.6238
# Epoch 10/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5978 - accuracy: 0.6386
# Epoch 11/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5822 - accuracy: 0.6634
# Epoch 12/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5687 - accuracy: 0.6881
# Epoch 13/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.6931
# Epoch 14/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5409 - accuracy: 0.7079
# Epoch 15/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5281 - accuracy: 0.7327
# Epoch 16/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5143 - accuracy: 0.7624
# Epoch 17/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.7822
# Epoch 18/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4898 - accuracy: 0.7921
# Epoch 19/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.8267
# Epoch 20/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4679 - accuracy: 0.8366
# Epoch 21/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4580 - accuracy: 0.8465
# Epoch 22/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.8515
# Epoch 23/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4402 - accuracy: 0.8515
# Epoch 24/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8614
# Epoch 25/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8614
# Epoch 26/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8663
# Epoch 27/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8663
# Epoch 28/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4003 - accuracy: 0.8713
# Epoch 29/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8713
# Epoch 30/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3866 - accuracy: 0.8713
# Epoch 31/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8663
# Epoch 32/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3741 - accuracy: 0.8663
# Epoch 33/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3682 - accuracy: 0.8762
# Epoch 34/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3624 - accuracy: 0.8762
# Epoch 35/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3571 - accuracy: 0.8762
# Epoch 36/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3521 - accuracy: 0.8812
# Epoch 37/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.8861
# Epoch 38/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8911
# Epoch 39/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8911
# Epoch 40/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8911
# Epoch 41/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8911
# Epoch 42/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8911
# Epoch 43/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3224 - accuracy: 0.8960
# Epoch 44/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3191 - accuracy: 0.9010
# Epoch 45/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3158 - accuracy: 0.8960
# Epoch 46/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3125 - accuracy: 0.8960
# Epoch 47/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.8911
# Epoch 48/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3066 - accuracy: 0.8960
# Epoch 49/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3037 - accuracy: 0.8960
# Epoch 50/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8960
# Epoch 51/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2982 - accuracy: 0.9010
# Epoch 52/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2955 - accuracy: 0.9158
# Epoch 53/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2931 - accuracy: 0.9158
# Epoch 54/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2905 - accuracy: 0.9158
# Epoch 55/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.9158
# Epoch 56/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.9158
# Epoch 57/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2837 - accuracy: 0.9158
# Epoch 58/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2817 - accuracy: 0.9158
# Epoch 59/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2798 - accuracy: 0.9158
# Epoch 60/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2776 - accuracy: 0.9158
# Epoch 61/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2759 - accuracy: 0.9158
# Epoch 62/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2740 - accuracy: 0.9158
# Epoch 63/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.9158
# Epoch 64/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2706 - accuracy: 0.9158
# Epoch 65/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.9158
# Epoch 66/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2672 - accuracy: 0.9158
# Epoch 67/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2656 - accuracy: 0.9158
# Epoch 68/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2641 - accuracy: 0.9158
# Epoch 69/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2626 - accuracy: 0.9158
# Epoch 70/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.9158
# Epoch 71/150
# 7/7 [==============================] - 0s 1000us/step - loss: 0.2598 - accuracy: 0.9158
# Epoch 72/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.9158
# Epoch 73/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2573 - accuracy: 0.9158
# Epoch 74/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2559 - accuracy: 0.9158
# Epoch 75/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9158
# Epoch 76/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2533 - accuracy: 0.9158
# Epoch 77/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2519 - accuracy: 0.9158
# Epoch 78/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2509 - accuracy: 0.9158
# Epoch 79/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2494 - accuracy: 0.9158
# Epoch 80/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2482 - accuracy: 0.9158
# Epoch 81/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.9158
# Epoch 82/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.9158
# Epoch 83/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.9158
# Epoch 84/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.9158
# Epoch 85/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2425 - accuracy: 0.9109
# Epoch 86/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.9109
# Epoch 87/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9109
# Epoch 88/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9109
# Epoch 89/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2379 - accuracy: 0.9109
# Epoch 90/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2367 - accuracy: 0.9109
# Epoch 91/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9109
# Epoch 92/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2341 - accuracy: 0.9109
# Epoch 93/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2328 - accuracy: 0.9158
# Epoch 94/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2319 - accuracy: 0.9158
# Epoch 95/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2302 - accuracy: 0.9208
# Epoch 96/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2293 - accuracy: 0.9208
# Epoch 97/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2281 - accuracy: 0.9208
# Epoch 98/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2272 - accuracy: 0.9208
# Epoch 99/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2261 - accuracy: 0.9208
# Epoch 100/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2250 - accuracy: 0.9208
# Epoch 101/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2242 - accuracy: 0.9208
# Epoch 102/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2232 - accuracy: 0.9208
# Epoch 103/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.9208
# Epoch 104/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2215 - accuracy: 0.9208
# Epoch 105/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2204 - accuracy: 0.9208
# Epoch 106/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2196 - accuracy: 0.9208
# Epoch 107/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9208
# Epoch 108/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2180 - accuracy: 0.9208
# Epoch 109/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9208
# Epoch 110/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2162 - accuracy: 0.9257
# Epoch 111/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2149 - accuracy: 0.9257
# Epoch 112/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.9307
# Epoch 113/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9307
# Epoch 114/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2129 - accuracy: 0.9307
# Epoch 115/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2118 - accuracy: 0.9307
# Epoch 116/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2110 - accuracy: 0.9307
# Epoch 117/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2103 - accuracy: 0.9307
# Epoch 118/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2095 - accuracy: 0.9307
# Epoch 119/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2088 - accuracy: 0.9307
# Epoch 120/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2081 - accuracy: 0.9356
# Epoch 121/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2074 - accuracy: 0.9356
# Epoch 122/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2068 - accuracy: 0.9356
# Epoch 123/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9356
# Epoch 124/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2055 - accuracy: 0.9356
# Epoch 125/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9356
# Epoch 126/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9356
# Epoch 127/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.9356
# Epoch 128/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2033 - accuracy: 0.9356
# Epoch 129/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2025 - accuracy: 0.9356
# Epoch 130/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.9356
# Epoch 131/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2015 - accuracy: 0.9356
# Epoch 132/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.9356
# Epoch 133/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2006 - accuracy: 0.9356
# Epoch 134/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2000 - accuracy: 0.9356
# Epoch 135/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9356
# Epoch 136/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1990 - accuracy: 0.9356
# Epoch 137/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9356
# Epoch 138/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1983 - accuracy: 0.9356
# Epoch 139/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1979 - accuracy: 0.9356
# Epoch 140/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.9356
# Epoch 141/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1968 - accuracy: 0.9356
# Epoch 142/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9356
# Epoch 143/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.9356
# Epoch 144/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1952 - accuracy: 0.9356
# Epoch 145/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.9356
# Epoch 146/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1941 - accuracy: 0.9356
# Epoch 147/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1939 - accuracy: 0.9356
# Epoch 148/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.9356
# Epoch 149/150
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1928 - accuracy: 0.9356
# Epoch 150/150
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1922 - accuracy: 0.9356

# %%
# Evaluate the model using the test data (SECOND ATTEMPT)
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.8057 - accuracy: 0.7353 - 27ms/epoch - 9ms/step
# Loss: 0.8057318329811096, Accuracy: 0.7352941036224365

# %%
def create_model(hp):
    nn_2_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_2_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=2), activation=activation, input_dim=input_features_total))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_2_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=2),
            activation=activation))
    
    nn_2_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_2_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_2_model

# %%
# Evaluate the model using the test data (SECOND ATTEMPT)
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.8057 - accuracy: 0.7353 - 28ms/epoch - 9ms/step
# Loss: 0.8057318329811096, Accuracy: 0.7352941036224365

# %%
# (THIRD ATTEMPT - ACCURACY 72%)
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes_layer1 = 20
hidden_nodes_layer2 = 20

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = input_features_total, activation = "tanh"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation = "sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="relu"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 20)                260
#
#  dense_8 (Dense)             (None, 20)                420
#
#  dense_9 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 701 (2.74 KB)
# Trainable params: 701 (2.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model (THIRD ATTEMPT)
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model (THIRD ATTEMPT)
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 4ms/step - loss: 1.5181 - accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9064 - accuracy: 0.5446
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6785 - accuracy: 0.6238
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6102 - accuracy: 0.6832
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.7178
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5229 - accuracy: 0.7525
# Epoch 7/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4877 - accuracy: 0.7871
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.8119
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.8218
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8267
# Epoch 11/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.8416
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3573 - accuracy: 0.8416
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3435 - accuracy: 0.8465
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8564
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3260 - accuracy: 0.8564
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3226 - accuracy: 0.8762
# Epoch 17/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.8663
# Epoch 18/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3149 - accuracy: 0.8663
# Epoch 19/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.8713
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 0.8663
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3066 - accuracy: 0.8663
# Epoch 22/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.8663
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3033 - accuracy: 0.8812
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8812
# Epoch 25/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8812
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2982 - accuracy: 0.8762
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2957 - accuracy: 0.8812
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8861
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2941 - accuracy: 0.8812
# Epoch 30/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.8812
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2922 - accuracy: 0.8861
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8861
# Epoch 33/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2901 - accuracy: 0.8762
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2868 - accuracy: 0.8762
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2852 - accuracy: 0.8812
# Epoch 36/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2839 - accuracy: 0.8861
# Epoch 37/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2832 - accuracy: 0.8812
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8812
# Epoch 39/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2810 - accuracy: 0.8812
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2807 - accuracy: 0.8861
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2799 - accuracy: 0.8911
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2783 - accuracy: 0.8861
# Epoch 43/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.8911
# Epoch 44/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8861
# Epoch 45/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2763 - accuracy: 0.8911
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2758 - accuracy: 0.8911
# Epoch 47/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2737 - accuracy: 0.8861
# Epoch 48/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2735 - accuracy: 0.8861
# Epoch 49/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2719 - accuracy: 0.8960
# Epoch 50/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.8960
# Epoch 51/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2704 - accuracy: 0.8960
# Epoch 52/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2700 - accuracy: 0.8911
# Epoch 53/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2687 - accuracy: 0.8911
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2686 - accuracy: 0.8960
# Epoch 55/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2670 - accuracy: 0.9010
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.8960
# Epoch 57/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2678 - accuracy: 0.8960
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2641 - accuracy: 0.9010
# Epoch 59/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.8960
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2684 - accuracy: 0.9059
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2704 - accuracy: 0.9010
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.9010
# Epoch 63/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.8960
# Epoch 64/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2635 - accuracy: 0.9010
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2603 - accuracy: 0.8960
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2586 - accuracy: 0.9010
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2593 - accuracy: 0.9010
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2607 - accuracy: 0.9059
# Epoch 69/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2600 - accuracy: 0.9059
# Epoch 70/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2587 - accuracy: 0.9059
# Epoch 71/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.9059
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2553 - accuracy: 0.9010
# Epoch 73/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2544 - accuracy: 0.9059
# Epoch 74/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2544 - accuracy: 0.9059
# Epoch 75/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2543 - accuracy: 0.9059
# Epoch 76/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2528 - accuracy: 0.9059
# Epoch 77/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.9059
# Epoch 78/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2512 - accuracy: 0.9059
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.9059
# Epoch 80/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.9059
# Epoch 81/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 0.9010
# Epoch 82/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.9059
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2481 - accuracy: 0.9059
# Epoch 84/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.9059
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2469 - accuracy: 0.9059
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9059
# Epoch 87/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9010
# Epoch 88/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2472 - accuracy: 0.9059
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2450 - accuracy: 0.9109
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.9059
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2432 - accuracy: 0.9059
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2429 - accuracy: 0.9059
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2411 - accuracy: 0.9059
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2406 - accuracy: 0.9059
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2408 - accuracy: 0.9059
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2407 - accuracy: 0.9059
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2395 - accuracy: 0.9059
# Epoch 98/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.9109
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 0.9059
# Epoch 100/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2365 - accuracy: 0.9109

# %%
# Evaluate the model using the test data (THIRD ATTEMPT)
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 3/3 - 0s - loss: 0.7976 - accuracy: 0.6912 - 97ms/epoch - 32ms/step
# Loss: 0.7976078987121582, Accuracy: 0.6911764740943909
